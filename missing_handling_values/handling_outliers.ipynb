# %% [markdown]
# ## 5 Number Summary and box plots

# %%
import numpy as np 

lst_marks = [12,34,45,54,66,56,45,34,34,21,86,34,23,6,74,45,33]

minimum, Q1, median, Q3, maximum = np.quantile(lst_marks, [0, 0.25, 0.50, 0.75, 1.0])

# %%
minimum, Q1, median, maximum
# Out:
# (np.float64(6.0), np.float64(33.0), np.float64(34.0), np.float64(86.0))

# %% [markdown]
# IQR Calculate Karna:
#
# IQR=Q
# 3
# ​
#  −Q
# 1
# ​
#
# Lower Boundary & Upper Boundary Set Karna:
#
# Lower Fence=Q
# 1
# ​
#  −(1.5×IQR)
#
# Upper Fence=Q
# 3
# ​
#  +(1.5×IQR)
#
# Outlier Identify Karna:
#
# Jo values Lower Fence se chhoti hon ya Upper Fence se badi hon, wo Outliers mani jayengi. Sir Python code se un abnormal/extreme values ko filter out karke remove karenge!

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# 21.0

# %%
LowerFence = Q1 - (1.5 * IQR)
HigherFence = Q3 + (1.5 * IQR)

print(LowerFence, HigherFence)
# Out:
# 1.5 85.5

# %%
import seaborn as sns

sns.boxplot(lst_marks)
# Out:
# <Axes: >
