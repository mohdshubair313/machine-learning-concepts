# %%
# how to read data from different sources like json and etc

import pandas as pd
from io import StringIO

Data = '{"employee": "James", "email": "james@gmail.com", "job_profile":[{"title": "Team Lead", "Title2": "Sr Machine learning Developer"}]}'

df = pd.read_json(StringIO(Data)) # storing this data frame in df

# %%
df.to_json() # this is for json conversion with index
# Out:
# '{"employee":{"0":"James"},"email":{"0":"james@gmail.com"},"job_profile":{"0":{"title":"Team Lead","Title2":"Sr Machine learning Developer"}}}'

# %%
df.to_json(orient='index')
# Out:
# '{"0":{"employee":"James","email":"james@gmail.com","job_profile":{"title":"Team Lead","Title2":"Sr Machine learning Developer"}}}'

# %%
# here we are using one sample csv file and read through data frames from pandas

df = pd.read_csv("Sample CSV file for importing contacts.csv")
df.head()

#now if you want to convert back to csv then 



df.to_csv("wine.csv")
# Out:
#    Title  First Name  Middle Name  Last Name  Suffix  Company  Department  \
# 0    NaN       Anita          NaN  Jorgensen     NaN  Contoso         NaN
# 1    NaN  Anne-Mette          NaN     Olesen     NaN  Contoso         NaN
# 2    NaN      Dorena          NaN    Paschke     NaN  Contoso         NaN
# 3    NaN       Kemal          NaN      Celik     NaN  Contoso         NaN
# 4    NaN      Shiori          NaN      Inoue     NaN  Contoso         NaN
#
#    Job Title  Business Street  Business Street 2  ...  Private  Profession  \
# 0        NaN              NaN                NaN  ...      NaN         NaN
# 1        NaN              NaN                NaN  ...      NaN         NaN
# 2        NaN              NaN                NaN  ...      NaN         NaN
# 3        NaN              NaN                NaN  ...      NaN         NaN
# 4        NaN              NaN                NaN  ...      NaN         NaN
#
# ...

# %%
import pandas as pd


url="https://en.wikipedia.org/wiki/Mobile_country_code"

df_list = pd.read_html(url, match="Country", header=0, storage_options={'User-Agent':'Mozilla/5.0'})

df = df_list[0]
df.head()
# Out:
#    Mobile country code                                    Country ISO 3166  \
# 0                  289                                 A Abkhazia    GE-AB
# 1                  412                                Afghanistan       AF
# 2                  276                                    Albania       AL
# 3                  603                                    Algeria       DZ
# 4                  544  American Samoa (United States of America)       AS
#
#                              Mobile network codes National MNC authority  \
# 0        List of mobile network codes in Abkhazia                    NaN
# 1     List of mobile network codes in Afghanistan                    NaN
# 2         List of mobile network codes in Albania                    NaN
# 3         List of mobile network codes in Algeria                    NaN
# 4  List of mobile network codes in American Samoa                    NaN
#
#                     Remarks
# 0  MCC is not listed by ITU
# ...

# %%
# reading (xlsx) excel file

pd.read_excel()
